# %%
ages = [19, 23, 19, 25, 21, 20, 25, 26, 25, 24]
ages.sort()
min_age = min(ages)
max_age = max(ages)

print("Min age:", min_age)
print("Max age:", max_age)

ages.append(min_age)
ages.append(max_age)
print("After adding min & max:", ages)

ages.sort()
n = len(ages)
if n % 2 == 0:
    median = (ages[n//2 - 1] + ages[n//2]) // 2
else:
    median = ages[n//2]

print("Sorted ages:", ages)
print("Median age:", median)


average = sum(ages) / len(ages)
print("Average age:", average)

age_range = max(ages) - min(ages)
print("Range:", age_range)
# Out:
# Min age: 19
# Max age: 26
# After adding min & max: [19, 19, 20, 21, 23, 24, 25, 25, 25, 26, 19, 26]
# Sorted ages: [19, 19, 19, 20, 21, 23, 24, 25, 25, 25, 26, 26]
# Median age: 23
# Average age: 22.666666666666668
# Range: 7
